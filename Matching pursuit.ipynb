# %% [markdown]
#    #                                   MOM matching - pursuit

# %%
import nbimporter
import progressbar
import numpy as np
import sklearn.datasets as sk_data
import matplotlib.pyplot as plt
from math import inf
import numpy.random as alea
import random as rd
from momAPI.Linear_models.MOM_matching_pursuit import mom_matching_pursuit
from momAPI.procedure.random_data import *
# Out:
# momAPI package
# In nn __init__
# In procedure __init__
# In Cross_validation __init__
# In Linear_models __init__

# %%
# %matplotlib notebook

# %%
n = 198
n_outliers = 2
features,sparsity = 50,10
sigma = 1
K = 5
iter_max = 200

t_0 = create_t_0(features,sparsity)
Y1,X1 = data1(n,t_0,sigma)
Y2,X2 = data2(n_outliers,features,type_outliers = 2)
Y,X = data_merge(Y1, X1, Y2, X2)

# %%
# %matplotlib notebook

D = sk_data.load_diabetes()
D1 = D.data
D2 = D.target.reshape((442,1))

B,C = regression_by_step(D1,D2)

xx  =  np.sum(np.abs(B), axis = 1)
xx /= xx[ - 1]

plt.plot(xx,B)
plt.title("Matching pursuit on diabete data")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
D = sk_data.load_diabetes()
D1 = D.data
D2 = D.target

# %%
model = mom_matching_pursuit(10)
model.fit(D1 , D2 , m = 10)
B = model.beta
xx  =  np.sum(np.abs(B), axis = 1)
xx /= xx[ - 1]

plt.plot(xx,B)
plt.title("Matching pursuit on diabete data")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
model = mom_matching_pursuit(8)
model.fit(X , Y , m = sparsity)
B = model.beta

xx  =  np.sum(np.abs(B), axis = 1)
xx /= xx[ - 1]

plt.plot(xx[ : - 1],B[ : - 1])
plt.title("MOM matching pursuit")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
